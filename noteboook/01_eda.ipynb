# %%
import pandas as pd

# %%
df1=pd.read_csv("..\data\loan_data.csv")

# %%
df1["loan_stress_index"] = df1["loan_amnt"] / df1["person_income"]
df1["credit_strength"] = df1["credit_score"] * df1["cb_person_cred_hist_length"]
df1["employment_stability"] = df1["person_emp_exp"] / df1["person_age"]

# %%
df1.corr(numeric_only=True)["loan_status"].sort_values()
# Out:
# person_income                -0.135808
# employment_stability         -0.024514
# person_age                   -0.021476
# person_emp_exp               -0.020481
# credit_strength              -0.015049
# cb_person_cred_hist_length   -0.014851
# credit_score                 -0.007647
# loan_amnt                     0.107714
# loan_int_rate                 0.332005
# loan_percent_income           0.384880
# loan_stress_index             0.385011
# loan_status                   1.000000
# Name: loan_status, dtype: float64
