# %%
import pandas as pd

# %%
df1=pd.read_csv("..\data\loan_data.csv")

# %%
df1["loan_stress_index"] = df["loan_amnt"] / df["person_income"]
df1["credit_strength"] = df["credit_score"] * df["cb_person_cred_hist_length"]
df1["employment_stability"] = df["person_emp_exp"] / df["person_age"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df1["loan_stress_index"] = df["loan_amnt"] / df["person_income"]
#       2 df1["credit_strength"] = df["credit_score"] * df["cb_person_cred_hist_length"]
#       3 df1["employment_stability"] = df["person_emp_exp"] / df["person_age"]
#
# NameError: name 'df' is not defined
